# %%
import json
import re

# Path to your JSONL file
file_path = '/external1/datasets/manifest_nemo/vils/valid_withpredictions.jsonl'

# Define precise regex patterns for each tag type
patterns = {
    'AGE': re.compile(r'\b(AGE_[0-9]+_[0-9]+)\b'),
    'GER': re.compile(r'\b(GER_[A-Z]+)\b'),
    'EMOTION': re.compile(r'\b(EMOTION_[A-Z]+)\b'),
    'INTENT': re.compile(r'\b(INTENT_[A-Z]+)\b'),
}

# Initialize dictionaries to store tag extractions
original = {tag: [] for tag in patterns}
predicted = {tag: [] for tag in patterns}

# Extract tags row-wise
with open(file_path, 'r', encoding='utf-8') as f:
    for line in f:
        obj = json.loads(line)
        text = obj.get('text', '')
        pred = obj.get('predicted_text', '')
        for tag, pattern in patterns.items():
            orig_match = pattern.search(text)
            pred_match = pattern.search(pred)
            original[tag].append(orig_match.group(1) if orig_match else None)
            predicted[tag].append(pred_match.group(1) if pred_match else None)

# Display the first 5 entries for each tag type
for tag in patterns:
    print(f"{tag}_original (first 5): {original[tag][:5]}")
    print(f"{tag}_predicted (first 5): {predicted[tag][:5]}")
    print()
# Out:
# AGE_original (first 5): ['AGE_30_45', 'AGE_45_60', 'AGE_18_30', 'AGE_45_60', 'AGE_18_30']
# AGE_predicted (first 5): ['AGE_30_45', 'AGE_30_45', 'AGE_30_45', 'AGE_18_30', 'AGE_30_45']
#
# GER_original (first 5): ['GER_FEMALE', 'GER_MALE', 'GER_MALE', 'GER_MALE', 'GER_FEMALE']
# GER_predicted (first 5): ['GER_MALE', 'GER_MALE', 'GER_MALE', 'GER_FEMALE', 'GER_FEMALE']
#
# EMOTION_original (first 5): ['EMOTION_SAD', 'EMOTION_SAD', 'EMOTION_SAD', 'EMOTION_SAD', 'EMOTION_SAD']
# EMOTION_predicted (first 5): ['EMOTION_SAD', 'EMOTION_SAD', 'EMOTION_SAD', 'EMOTION_SAD', 'EMOTION_HAP']
#
# INTENT_original (first 5): ['INTENT_UNCLEAR', 'INTENT_ASSERT', 'INTENT_INFORM', 'INTENT_INFORM', 'INTENT_START']
# INTENT_predicted (first 5): ['INTENT_GREET', 'INTENT_INFORM', 'INTENT_INFORM', 'INTENT_INFORM', 'INTENT_GREET']

# %%
import pandas as pd
from IPython.display import display

# Build and display confusion matrices for each tag
for tag in original:
    # Create DataFrame from the existing lists
    df = pd.DataFrame({
        'Actual': original[tag],
        'Predicted': predicted[tag]
    }).dropna()
    
    # Compute confusion matrix
    cm = pd.crosstab(df['Actual'], df['Predicted'])
    
    # Display
    print(f"### {tag} Confusion Matrix")
    display(cm)
# Out:
# ### AGE Confusion Matrix
# Predicted  AGE_18_18  AGE_18_30  AGE_18_45  AGE_30_30  AGE_30_45
# Actual
# AGE_0_18           2        115          5          0          3
# AGE_18_30          1        459         15          0         50
# AGE_30_45          0        217         14          3        212
# AGE_45_60          0         27          4          0         60
# ### GER Confusion Matrix
# Predicted   GER_FEMALE  GER_MALE
# Actual
# GER_FEMALE         436        59
# GER_MALE            41       659
# ### EMOTION Confusion Matrix
# Predicted    EMOTION_ANG  EMOTION_HAP  EMOTION_NEU  EMOTION_SAD
# Actual
# EMOTION_ANG           14            7           14            1
# EMOTION_HAP            4           18           77           30
# EMOTION_NEU            2            7          379           45
# EMOTION_SAD            8           10          133          447
# ### INTENT Confusion Matrix
# Predicted               INTENT_ACKNOWLEDGE  INTENT_ACTION  INTENT_EXPLAIN  \
# Actual
# INTENT_ACCEPT                            1              0               0
# INTENT_ACKNOWLEDGE                       1              0               0
# INTENT_ACKNOWLEDGEMENT                   1              0               0
# INTENT_ACTION                            0              1               0
# INTENT_ADVISE                            0              0               0
# INTENT_AFFIRM                            0              0               0
# INTENT_AGREEMENT                         0              0               0
# INTENT_APOLOGIZE                         0              0               0
# INTENT_APOLOGY                           0              0               0
# INTENT_ASSERT                            0              0               0
# INTENT_ASSESSMENT                        0              0               0
# INTENT_COMMAND                           0              0               0
# INTENT_COMMENT                           0              0               0
# INTENT_COMPARE                           0              0               0
# INTENT_CONFESS                           0              0               0
# INTENT_CONFIRM                           1              0               0
# INTENT_CONFUSED                          0              0               0
# INTENT_DECLINE                           0              0               0
# INTENT_DEFINE                            0              0               0
# INTENT_DEPART                            0              0               0
# INTENT_ERROR                             0              0               0
# INTENT_EXCLAMATION                       0              0               0
# INTENT_EXIT                              0              0               0
# INTENT_EXPLAIN                           0              0              17
# INTENT_EXPRESS                           0              0               0
# INTENT_EXPRESSION                        0              0               0
# INTENT_FEELING                           0              0               0
# INTENT_GO                                0              0               0
# INTENT_GOAL                              0              0               0
# INTENT_GRATITUDE                         0              0               0
# INTENT_GREET                             2              0               0
# INTENT_IDENTIFY                          0              0               0
# INTENT_INFORM                            4              0              10
# INTENT_INQUIRY                           0              0               0
# INTENT_INSTRUCT                          0              0               1
# INTENT_INSTRUCTION                       0              0               0
# INTENT_LEAVE                             0              0               0
# INTENT_NEGATIVE                          1              0               0
# INTENT_NONE                              1              0               0
# INTENT_OTHER                             1              0               0
# INTENT_PLAN                              0              0               0
# INTENT_PROCESS                           0              0               0
# INTENT_QUERY                             1              0               0
# INTENT_QUESTION                          0              0               1
# INTENT_REQUEST                           0              0               2
# INTENT_SILENCE                           0              0               0
# INTENT_SKIP                              0              0               0
# INTENT_START                             0              0               0
# INTENT_STATEMENT                         0              0               0
# INTENT_THANK                             1              0               0
# INTENT_THREATEN                          0              0               0
# INTENT_UNCERTAIN                         0              0               0
# INTENT_UNCLEAR                           0              0               0
# INTENT_UNKNOWN                           0              0               0
# INTENT_WAIT                              0              0               0
#
# Predicted               INTENT_GREET  INTENT_INFORM  INTENT_INSTRUCT  \
# Actual
# INTENT_ACCEPT                      0              0                0
# INTENT_ACKNOWLEDGE                10              2                0
# INTENT_ACKNOWLEDGEMENT             3              1                0
# INTENT_ACTION                      3              8                0
# INTENT_ADVISE                      0              2                0
# INTENT_AFFIRM                      0              2                0
# INTENT_AGREEMENT                   0              1                0
# INTENT_APOLOGIZE                   1              0                0
# INTENT_APOLOGY                     1              0                0
# INTENT_ASSERT                      0              5                0
# INTENT_ASSESSMENT                  0              1                0
# INTENT_COMMAND                     0              2                0
# INTENT_COMMENT                     0              1                0
# INTENT_COMPARE                     0              3                1
# INTENT_CONFESS                     0              0                0
# INTENT_CONFIRM                     1              5                0
# INTENT_CONFUSED                    0              1                0
# INTENT_DECLINE                     0              1                0
# INTENT_DEFINE                      0              1                0
# INTENT_DEPART                      0              3                0
# INTENT_ERROR                       0              1                0
# INTENT_EXCLAMATION                 1              0                0
# INTENT_EXIT                        0              1                0
# INTENT_EXPLAIN                     0            154                5
# INTENT_EXPRESS                     1              0                0
# INTENT_EXPRESSION                  3              1                0
# INTENT_FEELING                     0              1                0
# INTENT_GO                          1              0                0
# INTENT_GOAL                        0              1                0
# INTENT_GRATITUDE                   1              0                0
# INTENT_GREET                      34              4                0
# INTENT_IDENTIFY                    0              1                0
# INTENT_INFORM                      7            675                3
# INTENT_INQUIRY                     0              0                0
# INTENT_INSTRUCT                    0             13               14
# INTENT_INSTRUCTION                 0              4                0
# INTENT_LEAVE                       0              2                0
# INTENT_NEGATIVE                    3              1                0
# INTENT_NONE                        7              2                0
# INTENT_OTHER                       2              5                0
# INTENT_PLAN                        0              1                0
# INTENT_PROCESS                     0              2                0
# INTENT_QUERY                       0              0                0
# INTENT_QUESTION                    1              9                0
# INTENT_REQUEST                     2              2                5
# INTENT_SILENCE                     4              1                0
# INTENT_SKIP                        0              0                0
# INTENT_START                       1              0                0
# INTENT_STATEMENT                   1              3                0
# INTENT_THANK                       0              3                0
# INTENT_THREATEN                    1              0                0
# INTENT_UNCERTAIN                   1              0                0
# INTENT_UNCLEAR                     8              6                0
# INTENT_UNKNOWN                     1              1                0
# INTENT_WAIT                        0              1                0
#
# Predicted               INTENT_QUESTION  INTENT_REQUEST  INTENT_STATEMENT  \
# Actual
# INTENT_ACCEPT                         0               0                 0
# INTENT_ACKNOWLEDGE                    0               0                 0
# INTENT_ACKNOWLEDGEMENT                0               0                 0
# INTENT_ACTION                         0               0                 0
# INTENT_ADVISE                         0               0                 0
# INTENT_AFFIRM                         0               0                 0
# INTENT_AGREEMENT                      0               0                 0
# INTENT_APOLOGIZE                      0               0                 0
# INTENT_APOLOGY                        0               0                 0
# INTENT_ASSERT                         0               0                 0
# INTENT_ASSESSMENT                     0               0                 0
# INTENT_COMMAND                        0               0                 0
# INTENT_COMMENT                        0               0                 0
# INTENT_COMPARE                        0               0                 0
# INTENT_CONFESS                        0               1                 0
# INTENT_CONFIRM                        1               0                 0
# INTENT_CONFUSED                       0               0                 0
# INTENT_DECLINE                        0               0                 0
# INTENT_DEFINE                         0               0                 0
# INTENT_DEPART                         0               0                 0
# INTENT_ERROR                          0               0                 0
# INTENT_EXCLAMATION                    0               0                 0
# INTENT_EXIT                           0               0                 0
# INTENT_EXPLAIN                       11               0                 0
# INTENT_EXPRESS                        0               0                 0
# INTENT_EXPRESSION                     0               0                 0
# INTENT_FEELING                        0               0                 0
# INTENT_GO                             0               0                 0
# INTENT_GOAL                           0               0                 0
# INTENT_GRATITUDE                      0               0                 0
# INTENT_GREET                          1               0                 0
# INTENT_IDENTIFY                       0               0                 0
# INTENT_INFORM                         7               1                 0
# INTENT_INQUIRY                        2               0                 0
# INTENT_INSTRUCT                       2               1                 0
# INTENT_INSTRUCTION                    0               0                 0
# INTENT_LEAVE                          0               0                 0
# INTENT_NEGATIVE                       0               0                 0
# INTENT_NONE                           0               0                 0
# INTENT_OTHER                          0               0                 1
# INTENT_PLAN                           0               0                 0
# INTENT_PROCESS                        0               0                 0
# INTENT_QUERY                          0               0                 0
# INTENT_QUESTION                      41               0                 0
# INTENT_REQUEST                        2               1                 0
# INTENT_SILENCE                        0               0                 0
# INTENT_SKIP                           1               0                 0
# INTENT_START                          0               0                 0
# INTENT_STATEMENT                      0               0                 0
# INTENT_THANK                          0               0                 0
# INTENT_THREATEN                       0               0                 0
# INTENT_UNCERTAIN                      0               0                 0
# INTENT_UNCLEAR                        0               0                 0
# INTENT_UNKNOWN                        0               0                 0
# INTENT_WAIT                           0               0                 0
#
# Predicted               INTENT_UNCLEAR
# Actual
# INTENT_ACCEPT                        0
# INTENT_ACKNOWLEDGE                   0
# INTENT_ACKNOWLEDGEMENT               0
# INTENT_ACTION                        2
# INTENT_ADVISE                        0
# INTENT_AFFIRM                        0
# INTENT_AGREEMENT                     0
# INTENT_APOLOGIZE                     0
# INTENT_APOLOGY                       0
# INTENT_ASSERT                        0
# INTENT_ASSESSMENT                    0
# INTENT_COMMAND                       0
# INTENT_COMMENT                       0
# INTENT_COMPARE                       0
# INTENT_CONFESS                       0
# INTENT_CONFIRM                       1
# INTENT_CONFUSED                      0
# INTENT_DECLINE                       1
# INTENT_DEFINE                        0
# INTENT_DEPART                        1
# INTENT_ERROR                         0
# INTENT_EXCLAMATION                   0
# INTENT_EXIT                          0
# INTENT_EXPLAIN                       0
# INTENT_EXPRESS                       0
# INTENT_EXPRESSION                    0
# INTENT_FEELING                       0
# INTENT_GO                            0
# INTENT_GOAL                          0
# INTENT_GRATITUDE                     0
# INTENT_GREET                         2
# INTENT_IDENTIFY                      0
# INTENT_INFORM                        2
# INTENT_INQUIRY                       0
# INTENT_INSTRUCT                      0
# INTENT_INSTRUCTION                   0
# INTENT_LEAVE                         1
# INTENT_NEGATIVE                      0
# INTENT_NONE                          0
# INTENT_OTHER                         0
# INTENT_PLAN                          0
# INTENT_PROCESS                       0
# INTENT_QUERY                         0
# INTENT_QUESTION                      0
# INTENT_REQUEST                       0
# INTENT_SILENCE                       0
# INTENT_SKIP                          0
# INTENT_START                         1
# INTENT_STATEMENT                     0
# INTENT_THANK                         0
# INTENT_THREATEN                      0
# INTENT_UNCERTAIN                     0
# INTENT_UNCLEAR                       4
# INTENT_UNKNOWN                       0
# INTENT_WAIT                          0

# %%
from sklearn.metrics import f1_score, classification_report
import pandas as pd
from IPython.display import display

# Calculate and display F1 scores and full classification reports for each tag
for tag in original:
    y_true = original[tag]
    y_pred = predicted[tag]
    # Filter out entries where actual or predicted is None
    filtered = [(a, p) for a, p in zip(y_true, y_pred) if a is not None and p is not None]
    if not filtered:
        continue
    y_true_f, y_pred_f = zip(*filtered)
    
    # Full classification report as DataFrame
    report_dict = classification_report(y_true_f, y_pred_f, output_dict=True)
    df_report = pd.DataFrame(report_dict).T
    
    # Print tag header and display report
    print(f"### {tag} Classification Report")
    display(df_report)
    
    # Compute macro and micro F1
    macro_f1 = f1_score(y_true_f, y_pred_f, average='macro')
    micro_f1 = f1_score(y_true_f, y_pred_f, average='micro')
    print(f"{tag} Macro F1-score: {macro_f1:.3f}")
    print(f"{tag} Micro F1-score: {micro_f1:.3f}\n")
# Out:
# ### AGE Classification Report
# /home/compute/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/compute/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/compute/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/compute/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/compute/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/compute/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score      support
# AGE_0_18       0.000000  0.000000  0.000000   125.000000
# AGE_18_18      0.000000  0.000000  0.000000     0.000000
# AGE_18_30      0.561125  0.874286  0.683544   525.000000
# AGE_18_45      0.000000  0.000000  0.000000     0.000000
# AGE_30_30      0.000000  0.000000  0.000000     0.000000
# AGE_30_45      0.652308  0.475336  0.549935   446.000000
# AGE_45_60      0.000000  0.000000  0.000000    91.000000
# accuracy       0.565291  0.565291  0.565291     0.565291
# macro avg      0.173347  0.192803  0.176211  1187.000000
# weighted avg   0.493277  0.565291  0.508957  1187.000000
# AGE Macro F1-score: 0.176
# AGE Micro F1-score: 0.565
#
# ### GER Classification Report
#               precision    recall  f1-score      support
# GER_FEMALE     0.914046  0.880808  0.897119   495.000000
# GER_MALE       0.917827  0.941429  0.929478   700.000000
# accuracy       0.916318  0.916318  0.916318     0.916318
# macro avg      0.915937  0.911118  0.913299  1195.000000
# weighted avg   0.916261  0.916318  0.916074  1195.000000
# GER Macro F1-score: 0.913
# GER Micro F1-score: 0.916
#
# ### EMOTION Classification Report
#               precision    recall  f1-score      support
# EMOTION_ANG    0.500000  0.388889  0.437500    36.000000
# EMOTION_HAP    0.428571  0.139535  0.210526   129.000000
# EMOTION_NEU    0.628524  0.875289  0.731660   433.000000
# EMOTION_SAD    0.854685  0.747492  0.797502   598.000000
# accuracy       0.717391  0.717391  0.717391     0.717391
# macro avg      0.602945  0.537801  0.544297  1196.000000
# weighted avg   0.716169  0.717391  0.699518  1196.000000
# EMOTION Macro F1-score: 0.544
# EMOTION Micro F1-score: 0.717
#
# ### INTENT Classification Report
# /home/compute/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/compute/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/compute/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#                         precision    recall  f1-score      support
# INTENT_ACCEPT            0.000000  0.000000  0.000000     1.000000
# INTENT_ACKNOWLEDGE       0.066667  0.076923  0.071429    13.000000
# INTENT_ACKNOWLEDGEMENT   0.000000  0.000000  0.000000     5.000000
# INTENT_ACTION            1.000000  0.071429  0.133333    14.000000
# INTENT_ADVISE            0.000000  0.000000  0.000000     2.000000
# INTENT_AFFIRM            0.000000  0.000000  0.000000     2.000000
# INTENT_AGREEMENT         0.000000  0.000000  0.000000     1.000000
# INTENT_APOLOGIZE         0.000000  0.000000  0.000000     1.000000
# INTENT_APOLOGY           0.000000  0.000000  0.000000     1.000000
# INTENT_ASSERT            0.000000  0.000000  0.000000     5.000000
# INTENT_ASSESSMENT        0.000000  0.000000  0.000000     1.000000
# INTENT_COMMAND           0.000000  0.000000  0.000000     2.000000
# INTENT_COMMENT           0.000000  0.000000  0.000000     1.000000
# INTENT_COMPARE           0.000000  0.000000  0.000000     4.000000
# INTENT_CONFESS           0.000000  0.000000  0.000000     1.000000
# INTENT_CONFIRM           0.000000  0.000000  0.000000     9.000000
# INTENT_CONFUSED          0.000000  0.000000  0.000000     1.000000
# INTENT_DECLINE           0.000000  0.000000  0.000000     2.000000
# INTENT_DEFINE            0.000000  0.000000  0.000000     1.000000
# INTENT_DEPART            0.000000  0.000000  0.000000     4.000000
# INTENT_ERROR             0.000000  0.000000  0.000000     1.000000
# INTENT_EXCLAMATION       0.000000  0.000000  0.000000     1.000000
# INTENT_EXIT              0.000000  0.000000  0.000000     1.000000
# INTENT_EXPLAIN           0.548387  0.090909  0.155963   187.000000
# INTENT_EXPRESS           0.000000  0.000000  0.000000     1.000000
# INTENT_EXPRESSION        0.000000  0.000000  0.000000     4.000000
# INTENT_FEELING           0.000000  0.000000  0.000000     1.000000
# INTENT_GO                0.000000  0.000000  0.000000     1.000000
# INTENT_GOAL              0.000000  0.000000  0.000000     1.000000
# INTENT_GRATITUDE         0.000000  0.000000  0.000000     1.000000
# INTENT_GREET             0.343434  0.790698  0.478873    43.000000
# INTENT_IDENTIFY          0.000000  0.000000  0.000000     1.000000
# INTENT_INFORM            0.722698  0.952045  0.821668   709.000000
# INTENT_INQUIRY           0.000000  0.000000  0.000000     2.000000
# INTENT_INSTRUCT          0.500000  0.451613  0.474576    31.000000
# INTENT_INSTRUCTION       0.000000  0.000000  0.000000     4.000000
# INTENT_LEAVE             0.000000  0.000000  0.000000     3.000000
# INTENT_NEGATIVE          0.000000  0.000000  0.000000     5.000000
# INTENT_NONE              0.000000  0.000000  0.000000    10.000000
# INTENT_OTHER             0.000000  0.000000  0.000000     9.000000
# INTENT_PLAN              0.000000  0.000000  0.000000     1.000000
# INTENT_PROCESS           0.000000  0.000000  0.000000     2.000000
# INTENT_QUERY             0.000000  0.000000  0.000000     1.000000
# INTENT_QUESTION          0.602941  0.788462  0.683333    52.000000
# INTENT_REQUEST           0.250000  0.071429  0.111111    14.000000
# INTENT_SILENCE           0.000000  0.000000  0.000000     5.000000
# INTENT_SKIP              0.000000  0.000000  0.000000     1.000000
# INTENT_START             0.000000  0.000000  0.000000     2.000000
# INTENT_STATEMENT         0.000000  0.000000  0.000000     4.000000
# INTENT_THANK             0.000000  0.000000  0.000000     4.000000
# INTENT_THREATEN          0.000000  0.000000  0.000000     1.000000
# INTENT_UNCERTAIN         0.000000  0.000000  0.000000     1.000000
# INTENT_UNCLEAR           0.266667  0.222222  0.242424    18.000000
# INTENT_UNKNOWN           0.000000  0.000000  0.000000     2.000000
# INTENT_WAIT              0.000000  0.000000  0.000000     1.000000
# accuracy                 0.658863  0.658863  0.658863     0.658863
# macro avg                0.078196  0.063922  0.057686  1196.000000
# weighted avg             0.585057  0.658863  0.577992  1196.000000
# INTENT Macro F1-score: 0.058
# INTENT Micro F1-score: 0.659
